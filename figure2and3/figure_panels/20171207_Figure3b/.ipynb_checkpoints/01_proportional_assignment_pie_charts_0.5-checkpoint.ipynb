# %%
# Note, this is run for the data that HAVE NOT BEEN DOWNSAMPLED
# Read in the summary table of OTU matching to RTG reference genomes. 
# Plot pie charts for each variable region.

# %%
import pandas as pd

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library('ggplot2')
# library('cowplot')
# Out:
# /Users/johnsj/apps/apps/Python-2.7.10/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘cowplot’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /Users/johnsj/apps/apps/Python-2.7.10/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following object is masked from ‘package:ggplot2’:
#
#     ggsave
#
#
#   warnings.warn(x, RRuntimeWarning)

# %%
# %%R
# blank_theme <- theme_minimal()+
#   theme(
#   axis.title.x = element_blank(),
#   axis.title.y = element_blank(),
#   panel.border = element_blank(),
#   panel.grid=element_blank(),
#   axis.ticks = element_blank(),
#   plot.title=element_text(size=14, face="bold"))

# %%
# %%R
# # Multiple plot function
# #
# # ggplot objects can be passed in ..., or to plotlist (as a list of ggplot objects)
# # - cols:   Number of columns in layout
# # - layout: A matrix specifying the layout. If present, 'cols' is ignored.
# #
# # If the layout is something like matrix(c(1,2,3,3), nrow=2, byrow=TRUE),
# # then plot 1 will go in the upper left, 2 will go in the upper right, and
# # 3 will go all the way across the bottom.
# #
# multiplot <- function(..., plotlist=NULL, file, cols=1, layout=NULL) {
#   library(grid)
#
#   # Make a list from the ... arguments and plotlist
#   plots <- c(list(...), plotlist)
#
#   numPlots = length(plots)
#
#   # If layout is NULL, then use 'cols' to determine layout
#   if (is.null(layout)) {
#     # Make the panel
#     # ncol: Number of columns of plots
#     # nrow: Number of rows needed, calculated from # of cols
#     layout <- matrix(seq(1, cols * ceiling(numPlots/cols)),
#                     ncol = cols, nrow = ceiling(numPlots/cols))
#   }
#
#  if (numPlots==1) {
#     print(plots[[1]])
#
#   } else {
#     # Set up the page
#     grid.newpage()
#     pushViewport(viewport(layout = grid.layout(nrow(layout), ncol(layout))))
#
#     # Make each plot, in the correct location
#     for (i in 1:numPlots) {
#       # Get the i,j matrix positions of the regions that contain this subplot
#       matchidx <- as.data.frame(which(layout == i, arr.ind = TRUE))
#
#       print(plots[[i]], vp = viewport(layout.pos.row = matchidx$row,
#                                       layout.pos.col = matchidx$col))
#     }
#   }
# }

# %%
# start with the 0.5 distance
df = pd.read_table('00_data/distance_0.5_bacteroides_species_abundance_table.tsv', index_col=0)
df['Classification'] = ['Matches Wrong Genus', 'Matches Multiple Species', 
                       'Matches Single Species', 'No Match To Reference Database']
df.head()
# Out:
#                                     V1V3  V1V9                  Classification
# 01_Matches_wrong_genus_in_RTG          1     0             Matches Wrong Genus
# 02_Matches_multiple_species_in_RTG     6     4        Matches Multiple Species
# 03_Matches_single_species_in_RTG      20    10          Matches Single Species
# 04_Not_present_in_RTG                 16     4  No Match To Reference Database

# %%
print 'V1-V3', df['V1V3'].sum()
print 'V1-V9', df['V1V9'].sum()
# Out:
# V1-V3 43
# V1-V9 18

# %%
# %Rpush df

# %%
# %%R
# df$Classification = ordered(df$Classification, levels = c("Matches Wrong Genus", "Matches Multiple Species",
#                                                           "Matches Single Species", "No Match To Reference Database"))

# %%
# %%R
#
# pl1 <- ggplot(df, aes(x="", y=V1V3, fill=Classification)) + geom_bar(width = 1, stat = "identity")
# pl1 <- pl1 + coord_polar("y", start=0)
# pl1 <- pl1  + blank_theme +   theme(axis.text.x=element_blank())
# pl1 <- pl1 + ggtitle('V1-V3\n 99.5% Similarity') + theme(plot.title = element_text(hjust = 0.5))
# pl1 <- pl1 + scale_fill_manual(values=c('coral4', 'firebrick1', 'deepskyblue3', 'darkgray'))
# pl1 <- pl1 + theme(legend.title=element_blank())
# pl1

# %%
# %%R
# legend <- get_legend(pl1)
# ggdraw(legend)

# %%
# %%R
# pdf('01_legend.pdf')
# plot(pl1)
# dev.off()
# Out:
# quartz_off_screen
#                 2

# %%
# %%R
# pl2 <- ggplot(df, aes(x="", y=V1V3, fill=Classification)) + geom_bar(width = 1, stat = "identity")
# pl2 <- pl2 + coord_polar("y", start=0)
# pl2 <- pl2  + blank_theme +   theme(axis.text.x=element_blank())
# pl2 <- pl2 + ggtitle('V1-V3\n (43 OTUs)') + theme(plot.title = element_text(hjust = 0.5))
# pl2 <- pl2 + scale_fill_manual(values=c('coral4', 'firebrick1', 'deepskyblue3', 'darkgray'))
# pl2 <- pl2 + theme(legend.position='none')
# pl2

# %%
# %%R
# pl3 <- ggplot(df, aes(x="", y=V1V9, fill=Classification)) + geom_bar(width = 1, stat = "identity")
# pl3 <- pl3 + coord_polar("y", start=0)
# pl3 <- pl3  + blank_theme +   theme(axis.text.x=element_blank())
# pl3 <- pl3 + ggtitle('V1-V9\n (18 OTUs)') + theme(plot.title = element_text(hjust = 0.5))
# pl3 <- pl3 + scale_fill_manual(values=c('coral4', 'firebrick1', 'deepskyblue3', 'darkgray'))
# pl3 <- pl3 + theme(legend.position='none')
# pl3

# %%
# %%R
# multiplot(pl2, pl3, cols=2) #, ggdraw(legend), cols=3)

# %%
# %%R
# pdf('01_legend.pdf')
# ggdraw(legend)
# dev.off()
# Out:
# quartz_off_screen
#                 2

# %%
# %%R
# pdf('01_pie_charts_0.5.pdf', height=3, width=5)
# multiplot(pl2, pl3, cols=2)
# dev.off()
# Out:
# quartz_off_screen
#                 2
